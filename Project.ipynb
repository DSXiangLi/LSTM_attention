# %% [markdown]
# # "SPOKEN LANGUAGE UNDERSTANDING USING LONG SHORT-TERM MEMORY NEURAL NETWORKS" Implementation

# %% [markdown]
# ##### Experiment No. 1: normal  LSTM

# %%
#Word embedding 100: 
from project_main import test_rnnslu
test_rnnslu()
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 100
# nepochs: 60
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.1
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# epoch 0 out of 60
# NEW BEST: epoch 0 best test F1 81.07
# epoch 1 out of 60
# NEW BEST: epoch 1 best test F1 85.23
# epoch 2 out of 60
# NEW BEST: epoch 2 best test F1 89.19
# epoch 3 out of 60
# NEW BEST: epoch 3 best test F1 91.7
# epoch 4 out of 60
# NEW BEST: epoch 4 best test F1 92.94
# epoch 5 out of 60
# NEW BEST: epoch 5 best test F1 93.04
# epoch 6 out of 60
#
# epoch 7 out of 60
# NEW BEST: epoch 7 best test F1 93.11
# epoch 8 out of 60
# NEW BEST: epoch 8 best test F1 93.43
# epoch 9 out of 60
#
# epoch 10 out of 60
# NEW BEST: epoch 10 best test F1 93.8
# epoch 11 out of 60
# NEW BEST: epoch 11 best test F1 94.16
# epoch 12 out of 60
# NEW BEST: epoch 12 best test F1 94.18
# ...

# %%
#Word embedding 50: 
from project_main import test_rnnslu
test_rnnslu()
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# nepochs: 40
# fold: 3
# seed: 345
# emb_dimension: 50
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.1
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 84.26
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 88.89
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 89.62
# epoch 3 out of 40
# NEW BEST: epoch 3 best test F1 90.34
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 90.87
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 91.33
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 92.41
# epoch 7 out of 40
#
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 92.54
# epoch 9 out of 40
#
# epoch 10 out of 40
#
# epoch 11 out of 40
#
# epoch 12 out of 40
#
# epoch 13 out of 40
#
# epoch 14 out of 40
# NEW BEST: epoch 14 best test F1 92.6
# epoch 15 out of 40
#
# epoch 16 out of 40
#
# ...

# %%
#Word embedding 60: 
from project_main import test_rnnslu
test_rnnslu()
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 60
# nepochs: 40
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.1
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 88.94
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 91.98
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 92.2
# epoch 3 out of 40
#
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 92.77
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 93.05
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 93.46
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 93.57
# epoch 8 out of 40
#
# epoch 9 out of 40
# NEW BEST: epoch 9 best test F1 93.78
# epoch 10 out of 40
# NEW BEST: epoch 10 best test F1 94.01
# epoch 11 out of 40
#
# epoch 12 out of 40
#
# epoch 13 out of 40
#
# epoch 14 out of 40
#
# epoch 15 out of 40
# ...

# %%
#Word embedding 400: 
from project_main import test_rnnslu
test_rnnslu()
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# nepochs: 40
# fold: 3
# seed: 345
# emb_dimension: 400
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.1
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 92.34
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 93.72
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 94.56
# epoch 3 out of 40
# NEW BEST: epoch 3 best test F1 94.94
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 95.34
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 95.5
# epoch 6 out of 40
#
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 95.52
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 95.65
# epoch 9 out of 40
# NEW BEST: epoch 9 best test F1 95.76
# epoch 10 out of 40
# NEW BEST: epoch 10 best test F1 95.79
# epoch 11 out of 40
# NEW BEST: epoch 11 best test F1 95.82
# epoch 12 out of 40
#
# ...

# %% [markdown]
# ##### Experiment No. 2: LSTM with simplifications

# %% [markdown]
# (1) Close the input gate

# %%
#Word embedding 60: 
from project_main import test_rnnslu
test_rnnslu()
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 60
# nepochs: 40
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.1
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 58.62
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 70.39
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 75.31
# epoch 3 out of 40
# NEW BEST: epoch 3 best test F1 76.37
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 76.52
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 77.56
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 79.53
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 81.7
# epoch 8 out of 40
#
# epoch 9 out of 40
#
# epoch 10 out of 40
# NEW BEST: epoch 10 best test F1 82.62
# epoch 11 out of 40
# NEW BEST: epoch 11 best test F1 82.86
# epoch 12 out of 40
# NEW BEST: epoch 12 best test F1 83.76
# ...

# %%
#Word embedding 400:
from project_main import test_rnnslu
test_rnnslu()
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# nepochs: 40
# fold: 3
# seed: 345
# emb_dimension: 400
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.1
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 84.01
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 89.07
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 89.98
# epoch 3 out of 40
# NEW BEST: epoch 3 best test F1 91.45
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 92.26
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 92.68
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 93.25
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 93.76
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 94.11
# epoch 9 out of 40
# NEW BEST: epoch 9 best test F1 94.3
# epoch 10 out of 40
# NEW BEST: epoch 10 best test F1 94.58
# epoch 11 out of 40
# NEW BEST: epoch 11 best test F1 94.74
# ...

# %% [markdown]
# (2) Close the forget gate

# %%
#Word embedding 60:
from project_main import test_rnnslu
test_rnnslu()
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 60
# nepochs: 40
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.1
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 18.37
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 46.97
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 59.04
# epoch 3 out of 40
#
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 60.58
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 62.79
# epoch 6 out of 40
#
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 64.34
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 66.09
# epoch 9 out of 40
# NEW BEST: epoch 9 best test F1 67.89
# epoch 10 out of 40
# NEW BEST: epoch 10 best test F1 68.14
# epoch 11 out of 40
# NEW BEST: epoch 11 best test F1 69.85
# epoch 12 out of 40
# NEW BEST: epoch 12 best test F1 70.8
# ...

# %%
#Word embedding 400:
from project_main import test_rnnslu
test_rnnslu()
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# nepochs: 40
# fold: 3
# seed: 345
# emb_dimension: 400
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.1
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 58.94
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 75.89
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 83.65
# epoch 3 out of 40
# NEW BEST: epoch 3 best test F1 87.78
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 90.0
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 90.57
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 91.69
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 92.56
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 92.99
# epoch 9 out of 40
# NEW BEST: epoch 9 best test F1 93.3
# epoch 10 out of 40
# NEW BEST: epoch 10 best test F1 93.46
# epoch 11 out of 40
#
# epoch 12 out of 40
# ...

# %% [markdown]
# (3) Close the output gate

# %%
#Word embedding 60:
from project_main import test_rnnslu
test_rnnslu()
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 60
# nepochs: 40
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.1
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 50.46
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 58.62
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 61.03
# epoch 3 out of 40
# NEW BEST: epoch 3 best test F1 61.8
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 63.12
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 66.03
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 66.83
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 69.12
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 70.05
# epoch 9 out of 40
#
# epoch 10 out of 40
# NEW BEST: epoch 10 best test F1 71.48
# epoch 11 out of 40
#
# epoch 12 out of 40
# NEW BEST: epoch 12 best test F1 71.97
# ...

# %%
#Word embedding 400:
from project_main import test_rnnslu
test_rnnslu()
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# nepochs: 40
# fold: 3
# seed: 345
# emb_dimension: 400
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.1
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 93.13
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 94.27
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 94.77
# epoch 3 out of 40
# NEW BEST: epoch 3 best test F1 94.81
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 95.53
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 95.97
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 96.29
# epoch 7 out of 40
#
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 96.65
# epoch 9 out of 40
# NEW BEST: epoch 9 best test F1 96.89
# epoch 10 out of 40
#
# epoch 11 out of 40
# NEW BEST: epoch 11 best test F1 96.9
# epoch 12 out of 40
#
# epoch 13 out of 40
#
# epoch 14 out of 40
#
# ...

# %% [markdown]
# Plot best F1 score versus training iterations by simplified LSTM with forget gate fixed to 1.0 in round-marked curve, input gate fixed to 1.0 in triangle-marked curve, and output gate fixed to 1.0 in real curve.

# %%
import matplotlib.pyplot as plt
% matplotlib inline
no_input_gate = [84.01,89.07,89.98,91.45,92.26,92.68,93.25,93.76,94.11,94.3,94.58,94.74,94.95,94.95,95.06,95.16,95.24,
                 95.31,95.45,95.46,95.52,95.65,95.68,95.68,95.91,95.91,96.0,96.15,96.15,96.15,96.15,96.15,96.15,96.15,
                 96.27,96.31,96.34,96.34,96.34,96.4]
no_forget_gate = [58.94,75.89,83.65,87.78,90.0,90.57,91.69,92.56,92.99,93.3,93.46,93.46,93.56,93.72,93.76,93.93,94.07,
                  94.26,94.26,94.36,94.36,94.36,94.51,94.62,94.62,94.62,94.62,94.62,94.62,94.62,94.62,94.76,94.76,94.76,
                  94.76,94.76,94.76,94.76,94.76,94.76]
no_output_gate = [93.13,94.27,94.77,94.81,95.53,95.97,96.29,96.29,96.65,96.89,96.89,96.9,96.9,96.9,96.9,96.9,97.01,97.1,
                  97.1,97.1,97.1,97.1,97.1,97.1,97.1,97.13,97.13,97.15,97.15,97.17,97.17,97.17,97.17,97.17,97.17,97.17,
                  97.17,97.17,97.17,97.17]
plt.plot(list(range(40)), no_input_gate, marker='s', color='r', label='no input gating')
plt.plot(list(range(40)), no_forget_gate, marker='o', linestyle='--', color='b', label='no forget gating')
plt.plot(list(range(40)), no_output_gate, marker='x', linestyle='-.', color='g', label='no output gating')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.title('F1 score versus training iterations by simplified LSTM')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ##### Experiment No. 3: LSTM-ma(3)

# %%
from project_main import test_rnnslu
kwargs = {
    'lr': 0.02,
    'verbose': True,
    'decay': False,
    'win': 3,
    'nhidden': 300,
    'emb_dimension': 50,
    'nepochs': 40,
    'longdependence':'AR',
    'optimization':'Adagrad'
}
test_rnnslu(**kwargs)
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: AR
# nepochs: 40
# fold: 3
# seed: 345
# emb_dimension: 50
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.02
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 85.39
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 88.35
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 89.82
# epoch 3 out of 40
#
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 90.42
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 91.34
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 91.41
# epoch 7 out of 40
#
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 92.02
# epoch 9 out of 40
#
# epoch 10 out of 40
#
# epoch 11 out of 40
#
# epoch 12 out of 40
#
# epoch 13 out of 40
# NEW BEST: epoch 13 best test F1 92.16
# epoch 14 out of 40
#
# epoch 15 out of 40
#
# epoch 16 out of 40
#
# epoch 17 out of 40
# ...

# %%
from project_main import test_rnnslu
kwargs = {
    'lr': 0.02,
    'verbose': True,
    'decay': False,
    'win': 3,
    'nhidden': 300,
    'emb_dimension': 60,
    'nepochs': 40,
    'longdependence':'AR',
    'optimization':'Adagrad'
}
test_rnnslu(**kwargs)
# Out:
# verbose: True
# normal: False
# win: 3
# longdependence: AR
# nepochs: 40
# fold: 3
# seed: 345
# emb_dimension: 60
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.02
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 88.36
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 91.3
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 91.7
# epoch 3 out of 40
#
# epoch 4 out of 40
#
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 91.82
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 92.41
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 92.6
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 92.91
# epoch 9 out of 40
# NEW BEST: epoch 9 best test F1 93.02
# epoch 10 out of 40
# NEW BEST: epoch 10 best test F1 93.09
# epoch 11 out of 40
# NEW BEST: epoch 11 best test F1 93.19
# epoch 12 out of 40
# NEW BEST: epoch 12 best test F1 93.36
# epoch 13 out of 40
# ...

# %%
from project_main import test_rnnslu
kwargs = {
    'lr': 0.02,
    'verbose': True,
    'decay': False,
    'win': 3,
    'nhidden': 300,
    'emb_dimension': 400,
    'nepochs': 40,
    'longdependence':'AR',
    'optimization':'Adagrad'
}
test_rnnslu(**kwargs)
# Out:
# verbose: True
# normal: False
# win: 3
# longdependence: AR
# nepochs: 40
# fold: 3
# seed: 345
# emb_dimension: 400
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.02
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 94.11
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 94.31
# epoch 2 out of 40
#
# epoch 3 out of 40
# NEW BEST: epoch 3 best test F1 94.9
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 95.69
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 96.03
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 96.18
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 96.29
# epoch 8 out of 40
#
# epoch 9 out of 40
#
# epoch 10 out of 40
#
# epoch 11 out of 40
# NEW BEST: epoch 11 best test F1 96.42
# epoch 12 out of 40
#
# epoch 13 out of 40
# NEW BEST: epoch 13 best test F1 96.45
# epoch 14 out of 40
#
# epoch 15 out of 40
#
# epoch 16 out of 40
#
# ...

# %% [markdown]
# ##### Experiment No. 4: deep LSTM

# %%
#Word embedding 100: 
from deep_LSTM import test_rnnslu
test_rnnslu()
# Out:
# using GPU
# longdependence: None
# verbose: True
# normal: False
# nhidden2: 300
# win: 3
# nhidden1: 200
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 100
# nepochs: 40
# decay: False
# lr: 0.1
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 60.9
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 67.07
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 80.44
# epoch 3 out of 40
# NEW BEST: epoch 3 best test F1 85.54
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 88.7
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 91.02
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 91.8
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 92.23
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 92.75
# epoch 9 out of 40
# NEW BEST: epoch 9 best test F1 92.9
# epoch 10 out of 40
#
# epoch 11 out of 40
#
# epoch 12 out of 40
# ...

# %%
#Word embedding 60: 
from deep_LSTM import test_rnnslu
test_rnnslu()
# Out:
# using GPU
# longdependence: None
# verbose: True
# normal: False
# nhidden2: 300
# win: 3
# nhidden1: 200
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 60
# nepochs: 40
# decay: False
# lr: 0.1
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 55.06
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 57.5
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 69.92
# epoch 3 out of 40
# NEW BEST: epoch 3 best test F1 79.48
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 82.15
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 83.99
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 86.58
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 87.86
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 90.47
# epoch 9 out of 40
#
# epoch 10 out of 40
# NEW BEST: epoch 10 best test F1 91.1
# epoch 11 out of 40
#
# epoch 12 out of 40
# ...

# %%
#Word embedding 400: 
from deep_LSTM import test_rnnslu
test_rnnslu()
# Out:
# using GPU
# longdependence: None
# verbose: True
# normal: False
# nhidden2: 300
# win: 3
# nhidden1: 200
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 400
# nepochs: 40
# decay: False
# lr: 0.1
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 57.48
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 79.7
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 87.53
# epoch 3 out of 40
# NEW BEST: epoch 3 best test F1 91.01
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 92.53
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 93.23
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 94.06
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 94.07
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 94.41
# epoch 9 out of 40
# NEW BEST: epoch 9 best test F1 94.96
# epoch 10 out of 40
#
# epoch 11 out of 40
#
# epoch 12 out of 40
# ...

# %% [markdown]
# ##### Experiment No.5: Attention Model

# %%
from attention import test_rnnslu
kwargs = {
    'lr': 0.01,
    'verbose': True,
    'decay': False,
    'win': 3,
    'nhidden': 300,
    'emb_dimension': 50,
    'nepochs': 40,
    'longdependence':None,
    'optimization':'Adagrad'
}
test_rnnslu(**kwargs)
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# nepochs: 40
# fold: 3
# seed: 345
# emb_dimension: 50
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.01
# folder: ../result
# ... loading the dataset
# ... building the model
# x <class 'theano.tensor.var.TensorVariable'>
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 54.41
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 62.07
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 67.72
# epoch 3 out of 40
# NEW BEST: epoch 3 best test F1 70.79
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 73.71
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 75.6
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 76.86
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 77.26
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 77.95
# epoch 9 out of 40
#
# epoch 10 out of 40
# NEW BEST: epoch 10 best test F1 79.89
# epoch 11 out of 40
# ...

# %%
#Two activation functions in attention model: tanh tanh
from attention import test_rnnslu
kwargs = {
    'lr': 0.01,
    'verbose': True,
    'decay': False,
    'win': 3,
    'nhidden': 300,
    'emb_dimension': 400,
    'nepochs': 60,
    'longdependence':None,
    'optimization':'Adagrad'
}
test_rnnslu(**kwargs)
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# nepochs: 60
# fold: 3
# seed: 345
# emb_dimension: 400
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.01
# folder: ../result
# ... loading the dataset
# ... building the model
# x <class 'theano.tensor.var.TensorVariable'>
# ... training
# epoch 0 out of 60
# NEW BEST: epoch 0 best test F1 50.48
# epoch 1 out of 60
# NEW BEST: epoch 1 best test F1 70.09
# epoch 2 out of 60
# NEW BEST: epoch 2 best test F1 71.43
# epoch 3 out of 60
# NEW BEST: epoch 3 best test F1 77.56
# epoch 4 out of 60
# NEW BEST: epoch 4 best test F1 81.78
# epoch 5 out of 60
# NEW BEST: epoch 5 best test F1 81.86
# epoch 6 out of 60
# NEW BEST: epoch 6 best test F1 83.38
# epoch 7 out of 60
# NEW BEST: epoch 7 best test F1 84.46
# epoch 8 out of 60
# NEW BEST: epoch 8 best test F1 85.2
# epoch 9 out of 60
# NEW BEST: epoch 9 best test F1 85.58
# epoch 10 out of 60
# NEW BEST: epoch 10 best test F1 86.62
# ...

# %%
#Two activation functions in attention model: tanh sigmoid
from attention import test_rnnslu
kwargs = {
    'lr': 0.01,
    'verbose': True,
    'decay': False,
    'win': 3,
    'nhidden': 300,
    'emb_dimension': 400,
    'nepochs': 60,
    'longdependence':None,
    'optimization':'Adagrad'
}
test_rnnslu(**kwargs)
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# nepochs: 60
# fold: 3
# seed: 345
# emb_dimension: 400
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.01
# folder: ../result
# ... loading the dataset
# ... building the model
# x <class 'theano.tensor.var.TensorVariable'>
# ... training
# epoch 0 out of 60
# NEW BEST: epoch 0 best test F1 44.08
# epoch 1 out of 60
# NEW BEST: epoch 1 best test F1 70.61
# epoch 2 out of 60
# NEW BEST: epoch 2 best test F1 76.27
# epoch 3 out of 60
# NEW BEST: epoch 3 best test F1 79.39
# epoch 4 out of 60
# NEW BEST: epoch 4 best test F1 82.07
# epoch 5 out of 60
# NEW BEST: epoch 5 best test F1 83.94
# epoch 6 out of 60
# NEW BEST: epoch 6 best test F1 84.75
# epoch 7 out of 60
# NEW BEST: epoch 7 best test F1 84.84
# epoch 8 out of 60
# NEW BEST: epoch 8 best test F1 87.43
# epoch 9 out of 60
# NEW BEST: epoch 9 best test F1 87.99
# epoch 10 out of 60
# NEW BEST: epoch 10 best test F1 88.06
# ...

# %%
#Two activation functions in attention model: sigmoid sigmoid
from attention import test_rnnslu
kwargs = {
    'lr': 0.01,
    'verbose': True,
    'decay': False,
    'win': 3,
    'nhidden': 300,
    'emb_dimension': 400,
    'nepochs': 40,
    'longdependence':None,
    'optimization':'Adagrad'
}
test_rnnslu(**kwargs)
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# nepochs: 40
# fold: 3
# seed: 345
# emb_dimension: 400
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.01
# folder: ../result
# ... loading the dataset
# ... building the model
# x <class 'theano.tensor.var.TensorVariable'>
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 63.97
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 71.35
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 79.84
# epoch 3 out of 40
# NEW BEST: epoch 3 best test F1 82.39
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 83.9
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 85.78
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 86.84
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 87.55
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 88.26
# epoch 9 out of 40
#
# epoch 10 out of 40
# NEW BEST: epoch 10 best test F1 88.81
# epoch 11 out of 40
# ...

# %%
#Two activation functions in attention model: sigmoid sigmoid   / Learning rate 0.02
from attention import test_rnnslu
kwargs = {
    'lr': 0.02,
    'verbose': True,
    'decay': False,
    'win': 3,
    'nhidden': 300,
    'emb_dimension': 400,
    'nepochs': 40,
    'longdependence':None,
    'optimization':'Adagrad'
}
test_rnnslu(**kwargs)
# Out:
# using GPU
# verbose: True
# normal: False
# win: 3
# longdependence: None
# nepochs: 40
# fold: 3
# seed: 345
# emb_dimension: 400
# nhidden: 300
# decay: False
# optimization: Adagrad
# lr: 0.02
# folder: ../result
# ... loading the dataset
# ... building the model
# x <class 'theano.tensor.var.TensorVariable'>
# ... training
# epoch 0 out of 40
# NEW BEST: epoch 0 best test F1 66.74
# epoch 1 out of 40
# NEW BEST: epoch 1 best test F1 79.17
# epoch 2 out of 40
# NEW BEST: epoch 2 best test F1 82.53
# epoch 3 out of 40
# NEW BEST: epoch 3 best test F1 85.37
# epoch 4 out of 40
# NEW BEST: epoch 4 best test F1 88.3
# epoch 5 out of 40
# NEW BEST: epoch 5 best test F1 89.12
# epoch 6 out of 40
# NEW BEST: epoch 6 best test F1 89.21
# epoch 7 out of 40
# NEW BEST: epoch 7 best test F1 89.8
# epoch 8 out of 40
# NEW BEST: epoch 8 best test F1 91.76
# epoch 9 out of 40
# NEW BEST: epoch 9 best test F1 91.92
# epoch 10 out of 40
#
# epoch 11 out of 40
#
# epoch 12 out of 40
# ...
